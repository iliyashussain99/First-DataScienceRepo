# %% [markdown]
# "welcome iliyas"

# %%
'welcome iliyas'
# Out:
# 'welcome iliyas'

# %% [markdown]
# '''welcome iliyas'''

# %%
'''india
rose
bat
cat'''
# Out:
# 'india \nrose\nbat\ncat'

# %%
s='iliyas'

# %%
s
# Out:
# 'iliyas'

# %%
s[1]
# Out:
# 'l'

# %%
s[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2893730839.py in <cell line: 0>()
# ----> 1 s[6]
#
# IndexError: string index out of range

# %%
s[1:3]
# Out:
# 'li'

# %%
s[:]
# Out:
# 'iliyas'

# %%
10+5
# Out:
# 15

# %%
10/5
# Out:
# 2.0

# %%
10//5
# Out:
# 2

# %%
15/2
# Out:
# 7.5

# %%
rak=10
baz=15
print(rak)
print(baz)
gtb=30
print(gtb)
cut_=30
print(cut_)
pur*=55
print(pur*)
# Out:
#   File "/tmp/ipython-input-4230782677.py", line 10
#     print(pur*)
#               ^
# SyntaxError: invalid syntax

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
a=10
b=20
print(a)
print(b)
# Out:
# 10
# 20

# %%
print(10)
print(10,20)
print('python')
print(10,20,'python')
# Out:
# 10
# 10 20
# python
# 10 20 python

# %%
num1=20
num2=30
add=num1+num2
print(add)
# Out:
# 50

# %%
num1=20
num2=30
add=num1+num2
print('addition of ',num1, 'and',num2, 'is=',add)
# Out:
# addition of  20 and 30 is= 50

# %%
name='Python'
age=20
city='hyd'
print('My name is ',name,'and age is',age,'I am from city',city)
# Out:
# My name is  Python and age is 20 I am from city hyd

# %%
num1=20
num2=30
add=num1+num2
print('addition of {} and {} is={}'.format(num1,num2,add))
print('total of {} and {} is={}'.format(num1,num2,add))
# Out:
# addition of 20 and 30 is=50
# total of 20 and 30 is=50

# %%
num1=100
num2=25
num3=333
avg=(num1+num2+num3)/3 # or we can use avg=round(num1+num2+num3)/3,2)
avg1=round((num1+num2+num3)/3,2)
# The avrage of num1,num2,num3 is = avg
print('The avrage of {}, {}, and {} is= {} or {}'.format(num1,num2,num3,avg,avg1))
# Out:
# The avrage of 100, 25, and 333 is= 152.66666666666666 or 152.67

# %%
print(f'The addition of {num1} and {num2} is= {add}')
print(f'hello my name is {name}, and i am {age} year old, from {city}.')
# Out:
# The addition of 100 and 25 is= 50
# hello my name is Python, and i am 20 year old, from hyd.

# %%
print('hello') # 1st statement
print('good moorning') # 2nd statement)
# Out:
# hello
# good moorning

# %%
print('hello', end=
' ') # 1st statement
print('world good day')
# Out:
# hello world good day

# %%
print('hello' ,end=' ') # 1st statement
print('good moorning') # 2nd statement)
# Out:
# hello good moorning

# %%
num1=20
num2=30
add=num1+num2
print(f'The addition of {num1} and {num2} is= {add}')
# Out:
# The addition of 20 and 30 is= 50

# %%
print(3,'.')
# Out:
# 3 .

# %%
print(3,'.', sep='')
# Out:
# 3.

# %%
import numpy as np
a1=np.nan
type(a1)
# Out:
# float

# %%
print(True*2)
# Out:
# 2

# %%
f1=2e1
f1
# Out:
# 20.0

# %%
f2 = 3e2
f2
# Out:
# 300.0

# %%
c = 1 + 2j
print(type(c))
# Out:
# <class 'complex'>

# %%
c = 2.3 + 56j
c
# Out:
# (2.3+56j)

# %%
c2 = 2 + 3.6J
c2
# Out:
# (2+3.6j)

# %%
c3 = 5.6 + 6.3j
c3
# Out:
# (5.6+6.3j)

# %%
p = 10
q = 10
r = 30
print(id(p))
print(id(q))
print(id(r))
# Out:
# 11654664
# 11654664
# 11655304

# %%
s = 'iliyas'
print(s[2])
print(s[-3])
s[-5]
# Out:
# i
# y
# 'l'

# %%
u = 'November'
print(u[2:6])
print(u[-7:-3])
print(u[2:15])
print(u[-8:-2])
print(u[0:7])
print(u[-7:-6])
# Out:
# vemb
# ovem
# vember
# Novemb
# Novembe
# o

# %%
str = """ Welcome to string
and new test
basic """
str
# Out:
# ' Welcome to string \nand new test\nbasic '

# %%
str2 = ''' Welcome to string
and new test
basic '''
str2
# Out:
# ' Welcome to string \nand new test\nbasic '

# %%
# Type Casting

# %% [markdown]
# # Type Casting

# %%
int(2.6)
# Out:
# 2

# %%
int(2.789)
# Out:
# 2

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1854362543.py in <cell line: 0>()
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
float(2)
# Out:
# 2.0

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(10,20)
# Out:
# (10+20j)

# %%
complex(True,False)
# Out:
# (1+0j)

# %%
complex(False,True)
# Out:
# 1j

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(3.6)
# Out:
# True

# %%
bool(1+2j)
# Out:
# True

# %%
print(str(10.6))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1906068233.py in <cell line: 0>()
# ----> 1 print(str(10.6))
#
# TypeError: 'str' object is not callable

# %%
# !python --version
# Out:
# Python 3.12.12

# %%
# !python -V
# Out:
# Python 3.12.12

# %%
import sys
print(sys.version)
print(sys.version.split()[0])
print(f'(Python version: {sys.version.split()[0]})')
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# 3.12.12
# (Python version: 3.12.12)

# %%
l =[]
l
# Out:
# []

# %%
len(l)
# Out:
# 0

# %%
type(l)
# Out:
# list

# %%
l1 = list()
type(l1)
# Out:
# list

# %%
l1.append(10)

# %%
l1.append(2.3)
l1
# Out:
# [10, 2.3, 2.3, 2.3]

# %%
l1.append('got')

# %%
l1
# Out:
# [10, 'got']

# %%
l2 = l1.copy()
l2
# Out:
# [10, 'got']

# %%
l1 == l2
# Out:
# True

# %%
l2[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2417620317.py in <cell line: 0>()
# ----> 1 l2[3]
#
# IndexError: list index out of range

# %%
l2[:]
# Out:
# [10, 'got']

# %%
l2[1:5]
# Out:
# ['got']

# %%
l2[:-2]
# Out:
# []

# %%
l2[::-1]
# Out:
# ['got', 10]

# %%
l2[::-2]
# Out:
# ['got']

# %%
l3 = list()

# %%
l3.append(10)
l3
# Out:
# [10]

# %%
l4 = [1,2,3,4,5]
l4
# Out:
# [1, 2, 3, 4, 5]

# %%
l4.append(3)
l4
# Out:
# [1, 2, 3, 4, 5, 3]

# %%
l4.append(2.6)
l4
# Out:
# [1, 2, 3, 4, 5, 3, 2.6]

# %%
l4.append('iliyas')
l4
# Out:
# [1, 2, 3, 4, 5, 3, 2.6, 'iliyas']

# %%
l4.append([1,2,3])
l4
# Out:
# [1, 2, 3, 4, 5, 3, 2.6, 'iliyas', [1, 2, 3]]

# %%
len(l4)
# Out:
# 8

# %%
l4[8]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2040409349.py in <cell line: 0>()
# ----> 1 l4[8]
#
# IndexError: list index out of range

# %%
l4[8][1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2109969887.py in <cell line: 0>()
# ----> 1 l4[8][1]
#
# IndexError: list index out of range

# %%
l3.append(2+3j)
l3
# Out:
# [10, (2+3j)]

# %%
l3.clear()
l3
# Out:
# []

# %%
len(l3)
# Out:
# 0

# %%
l4
# Out:
# [1, 2, 3, 4, 5, 3, 2.6, 'iliyas']

# %%
l4.remove(3)

# %%
l4
# Out:
# [1, 2, 4, 5, 3, 2.6, 'iliyas']

# %%
l4.pop(5)
# Out:
# 2.6

# %%
l4
# Out:
# [1, 2, 4, 5, 3, 'iliyas']

# %%
l3
# Out:
# []

# %%
l3.extend(l4)
l3
# Out:
# [1, 2, 4, 5, 3, 'iliyas']

# %%
l3.insert(1,30)
l3
# Out:
# [1, 30, 30, 2, 4, 5, 3, 'iliyas']

# %%
l3.sort()
l3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3591807561.py in <cell line: 0>()
# ----> 1 l3.sort()
#       2 l3
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
l5 = [1,6,2,9,7,19,12,15]
l5
# Out:
# [1, 6, 2, 9, 7, 19, 12, 15]

# %%
l5.sort()
l5
# Out:
# [1, 2, 6, 7, 9, 12, 15, 19]

# %%
l5.sort(reverse=True)
l5
# Out:
# [19, 15, 12, 9, 7, 6, 2, 1]

# %%
l5.sort(reverse=False)
l5
# Out:
# [1, 2, 6, 7, 9, 12, 15, 19]
